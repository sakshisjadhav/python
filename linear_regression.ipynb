# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshisjadhav/python/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# Path to where the results are hosted online
# This loads the data into a Pandas dataframe
Data=pd.read_csv('https://raw.githubusercontent.com/sakshisjadhav/python/main/try_linear.csv', sep=',')

# Macro to help with presenting the final plot.
# %matplotlib inline


# This is the call creating the graph.
# data=Data       : source of data
# x='Distance'    : column label data to use on x axis 
# y='Measurement' : column label data to use on y axis
# kind='line'     : make a line plot
# height=5        : size of the plot height
# aspect=2        : multiplier for width of plot from height
# ci=95           : confidence interval for shaded region
colours = dict(zip(Data['speed'].unique(), sns.color_palette(n_colors=len(Data['speed'].unique()))))


sns.relplot(data=Data, x='Angle', y='error', hue='speed', kind='line', height=7, aspect=3, legend='full', palette=colours, marker='o')



plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# Path to where the results are hosted online
# This loads the data into a Pandas dataframe
Data0=pd.read_csv('https://raw.githubusercontent.com/sakshisjadhav/python/main/speed20.csv', sep=',')
#Data0.head()
# Macro to help with presenting the final plot.
# %matplotlib inline


# This is the call creating the graph.
# data=Data       : source of data
# x='Distance'    : column label data to use on x axis 
# y='Measurement' : column label data to use on y axis
# kind='line'     : make a line plot
# height=5        : size of the plot height
# aspect=2        : multiplier for width of plot from height
# ci=95           : confidence interval for shaded region

sns.relplot(data=Data0, x='angle', y='error', kind='line', height=7, aspect=3, legend='full',marker='o',color='y')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

Data0=pd.read_csv('https://raw.githubusercontent.com/sakshisjadhav/python/main/speed20.csv', sep=',')

# %matplotlib inline

Data0.corr()
# Out:
#           angle     error
# angle  1.000000  0.999939
# error  0.999939  1.000000

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression



# Path to where the results are hosted online
# This loads the data into a Pandas dataframe
Data1=pd.read_csv('https://raw.githubusercontent.com/sakshisjadhav/python/main/speed40.csv', sep=',')

# Macro to help with presenting the final plot.
# %matplotlib inline



sns.relplot(data=Data1, x='angle', y='error', kind='line', height=5, aspect=3, legend='full', color='r',marker='o')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

Data0=pd.read_csv('https://raw.githubusercontent.com/sakshisjadhav/python/main/speed40.csv', sep=',')

# %matplotlib inline

Data0.corr()
# Out:
#           angle     error
# angle  1.000000  0.988355
# error  0.988355  1.000000

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression



# Path to where the results are hosted online
# This loads the data into a Pandas dataframe
Data1=pd.read_csv('https://raw.githubusercontent.com/sakshisjadhav/python/main/speed60.csv', sep=',')

# Macro to help with presenting the final plot.
# %matplotlib inline



sns.relplot(data=Data1, x='angle', y='error', kind='line', height=5, aspect=3, legend='full', color='r',marker='o')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

Data0=pd.read_csv('https://raw.githubusercontent.com/sakshisjadhav/python/main/speed60.csv', sep=',')

# %matplotlib inline

Data0.corr()
# Out:
#           angle     error
# angle  1.000000  0.943476
# error  0.943476  1.000000

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# Path to where the results are hosted online
# This loads the data into a Pandas dataframe
Data1=pd.read_csv('https://raw.githubusercontent.com/sakshisjadhav/python/main/speed80.csv', sep=',')

# Macro to help with presenting the final plot.
# %matplotlib inline



sns.relplot(data=Data1, x='angle', y='error', kind='line', height=5, aspect=3, legend='full', color='g',marker='o')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

Data0=pd.read_csv('https://raw.githubusercontent.com/sakshisjadhav/python/main/speed80.csv', sep=',')

# %matplotlib inline

Data0.corr()
# Out:
#           angle     error
# angle  1.000000  0.886354
# error  0.886354  1.000000

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# Path to where the results are hosted online
# This loads the data into a Pandas dataframe
Data1=pd.read_csv('https://raw.githubusercontent.com/sakshisjadhav/python/main/csv1.csv', sep=',')

# Macro to help with presenting the final plot.
# %matplotlib inline



sns.relplot(data=Data1, x='angle', y='error', kind='line', height=5, aspect=3, legend='full', color='b',marker='o')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

Data0=pd.read_csv('https://raw.githubusercontent.com/sakshisjadhav/python/main/csv1.csv', sep=',')

# %matplotlib inline

Data0.corr()
# Out:
#           angle     error
# angle  1.000000  0.919039
# error  0.919039  1.000000
